# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("./dataset/CovidData.csv")
print(len(df.T))
df.head().T
# Out:
# 21
#                                0           1           2           3  \
# USMER                          2           2           2           2
# MEDICAL_UNIT                   1           1           1           1
# SEX                            1           2           2           1
# PATIENT_TYPE                   1           1           2           1
# DATE_DIED             03/05/2020  03/06/2020  09/06/2020  12/06/2020
# INTUBED                       97          97           1          97
# PNEUMONIA                      1           1           2           2
# AGE                           65          72          55          53
# PREGNANT                       2          97          97           2
# DIABETES                       2           2           1           2
# COPD                           2           2           2           2
# ASTHMA                         2           2           2           2
# ...

# %%
pd.to_numeric(df.CLASIFFICATION_FINAL,errors='coerce')
# Out:
# 0          3
# 1          5
# 2          3
# 3          7
# 4          3
#           ..
# 1048570    7
# 1048571    7
# 1048572    7
# 1048573    7
# 1048574    7
# Name: CLASIFFICATION_FINAL, Length: 1048575, dtype: int64
